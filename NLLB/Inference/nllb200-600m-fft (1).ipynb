# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer and model for Arabic to English translation
tokenizer = AutoTokenizer.from_pretrained("yasmineee/finetune-NLLB-600M-on-opus100-Ar2En-without-optimization")
model = AutoModelForSeq2SeqLM.from_pretrained("yasmineee/finetune-NLLB-600M-on-opus100-Ar2En-without-optimization")

def translate(text, model, tokenizer, max_length=100, num_beams=5):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)
    
    # Generate the translation using the model
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True
    )
    
    # Decode the output tokens to get the translated text
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    return translated_text

# Example usage
text = "بما في ذلك التعليم، والصحة، والتكنولوجيا."  # Arabic text to translate
translated_text = translate(text, model, tokenizer)
print("Translation:", translated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/39.9k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/4.23k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/897 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/176 [00:00<?, ?B/s]
# Translation: Including education, health and technology.

# %%
text = ".قررت أن أغير وظيفتي لأبحث عن فرص جديدة"
translated_text2 = translate(text, model, tokenizer)
print("Translation:", translated_text2)
# Out:
# Translation: I decided to change jobs to look for new opportunities.

# %%
text = "الطريق إلى النجاح مليء بالتحديات."
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: The road to success is paved with challenges.

# %%
text = "هل هذا المكان مزدحم دائمًا؟"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: Is this place always crowded?

# %%
text = "سأفكر في الأمر"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: I'll think about it.

# %%
text = "ما رأيك"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: What do you think?

# %%
text = "السَّيْفُ أَصْدَقُ إِنْبَاءً مِنَ الكُتُبِ في حدهِ الحدُّ بينَ الجدِّ واللَّعبِ"
translated_text6 = translate(text, model, tokenizer)
print("Translation:", translated_text6)
# Out:
# Translation: The sword. I believe a prophecy from a book alone about the boundary between seriousness and play.

# %%
text = "كان يوماً طويلاً"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: It's been a long day.

# %%
text = "السيف اصدق انباءا من الكتب في حده الحد بين الجد و اللعب"
translated_text6 = translate(text, model, tokenizer)
print("Translation:", translated_text6)
# Out:
# Translation: The sword believed the prophecies of the books in the boundary between grandfather and play.
