# %%
# !pip install transformers

# %%
# !pip install peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from peft import PeftModel, PeftConfig
from transformers import AutoModelForSeq2SeqLM
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/AraT5v2-base-1024")

config = PeftConfig.from_pretrained("yasmineee/araT5-Base-with-QDoRA")
base_model = AutoModelForSeq2SeqLM.from_pretrained("UBC-NLP/AraT5v2-base-1024")
model = PeftModel.from_pretrained(base_model, "yasmineee/araT5-Base-with-QDoRA")


def translate(text, model, tokenizer, max_length=50, num_beams=5):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_length=max_length,
        num_beams=num_beams,
        length_penalty=1.0,
        early_stopping=True,
        do_sample=True,
        top_k=120,
        top_p=0.95
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example usage
text = "translate Arabic to English: بما في ذلك التعليم، والصحة، والتكنولوجيا."
translated_text = translate(text, model, tokenizer)
print("Translation:", translated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.37k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/4.93M [00:00<?, ?B/s]
# ...

# %%
text = "translate Arabic to English: .قررت أن أغير وظيفتي لأبحث عن فرص جديدة"
translated_text2 = translate(text, model, tokenizer)
print("Translation:", translated_text2)
# Out:
# Translation: (i) I decided to change my job to find new opportunities.

# %%
text = "translate Arabic to English: الطريق إلى النجاح مليء بالتحديات."
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: The road to success is مليئا challenges.

# %%
text = "translate Arabic to English: هل هذا المكان مزدحم دائمًا؟"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: This place is permanent ازدحام.

# %%
text = "translate Arabic to English: سأفكر في الأمر"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: I will understand the matter.

# %%
text = "translate Arabic to English: ما هو رأيك؟"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: What is رأيك؟

# %%
text = "translate Arabic to English: كان يوماً طويلاً"
translated_text3 = translate(text, model, tokenizer)
print("Translation:", translated_text3)
# Out:
# Translation: It had been long-term day

# %%
text = "translate Arabic to English: السَّيْفُ أَصْدَقُ إِنْبَاءً مِنَ الكُتُبِ في حدهِ الحدُّ بينَ الجدِّ واللَّعبِ"
translated_text6 = translate(text, model, tokenizer)
print("Translation:", translated_text6)
# Out:
# Translation: The printing of books are expenditure to the time and the game.

# %%
text = "translate Arabic to English: السيف اصدق انباءا من الكتب في حده الحد بين الجد و اللعب"
translated_text6 = translate(text, model, tokenizer)
print("Translation:", translated_text6)
# Out:
# Translation: The السيف is the best evidence of books in the same line between the argument and play
